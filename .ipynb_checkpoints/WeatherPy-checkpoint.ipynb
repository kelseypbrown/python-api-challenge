# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 611

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port arthur
# Processing Record 2 of Set 1 | petropavlovsk-kamchatsky
# Processing Record 3 of Set 1 | bilibino
# Processing Record 4 of Set 1 | fale old settlement
# Processing Record 5 of Set 1 | kodinsk
# Processing Record 6 of Set 1 | tindouf
# Processing Record 7 of Set 1 | chibougamau
# Processing Record 8 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 1 | port douglas
# Processing Record 10 of Set 1 | college
# Processing Record 11 of Set 1 | st. john's
# Processing Record 12 of Set 1 | mascote
# Processing Record 13 of Set 1 | olonkinbyen
# Processing Record 14 of Set 1 | albany
# Processing Record 15 of Set 1 | raghunathpur
# Processing Record 16 of Set 1 | brezina
# Processing Record 17 of Set 1 | cururupu
# Processing Record 18 of Set 1 | buta
# Processing Record 19 of Set 1 | midland
# Processing Record 20 of Set 1 | ketchikan
# Processing Record 21 of Set 1 | udachny
# Processing Record 22 of Set 1 | waitangi
# Processing Record 23 of Set 1 | iqaluit
# Processing Record 24 of Set 1 | trenggalek
# Processing Record 25 of Set 1 | port hedland
# Processing Record 14 of Set 4 | adamovka
# Processing Record 15 of Set 4 | saldanha
# Processing Record 16 of Set 4 | chernyshevskiy
# Processing Record 17 of Set 4 | yuzhno-kurilsk
# Processing Record 18 of Set 4 | saipan
# Processing Record 19 of Set 4 | nemuro
# Processing Record 20 of Set 4 | midvagur
# Processing Record 21 of Set 4 | nuuk
# Processing Record 22 of Set 4 | rio grande
# Processing Record 23 of Set 4 | whitehorse
# Processing Record 24 of Set 4 | mukalla
# Processing Record 25 of Set 4 | sitka
# Processing Record 26 of Set 4 | montijo
# Processing Record 27 of Set 4 | kodiak
# Processing Record 28 of Set 4 | alaghsas
# Processing Record 29 of Set 4 | port saint john's
# Processing Record 30 of Set 4 | chonchi
# Processing Record 31 of Set 4 | verkhnevilyuysk
# Processing Record 32 of Set 4 | akureyri
# Processing Record 33 of Set 4 | san juan
# Processing Record 34 of Set 4 | ambon
# Processing Record 35 of Set 4 | salalah
# Processing Record 36 of Set 4 | emporia
# Processing Record 37 of Set 4 | deniliquin
# Processing Record 38 of Set 4 | alakurtti
# Processing Record 39 of Set 4 | sinabang
# Processing Record 40 of Set 4 | east london
# Processing Record 41 of Set 4 | san ignacio
# Processing Record 42 of Set 4 | newman
# Processing Record 43 of Set 4 | banda aceh
# Processing Record 44 of Set 4 | ola
# Processing Record 45 of Set 4 | antofagasta
# Processing Record 46 of Set 4 | huarmey
# Processing Record 47 of Set 4 | sao joao da barra
# Processing Record 48 of Set 4 | kiruna
# Processing Record 49 of Set 4 | polyarnyy
# Processing Record 0 of Set 5 | kulhudhuffushi
# Processing Record 1 of Set 5 | hamilton
# Processing Record 2 of Set 5 | inderbor
# Processing Record 3 of Set 5 | enewetak
# Processing Record 4 of Set 5 | acapulco de juarez
# Processing Record 5 of Set 5 | cable beach
# City not found. Skipping...
# Processing Record 6 of Set 5 | quelimane
# Processing Record 7 of Set 5 | eyl
# Processing Record 8 of Set 5 | susuman
# Processing Record 9 of Set 5 | choma
# Processing Record 10 of Set 5 | tolanaro
# Processing Record 11 of Set 5 | puerto deseado
# Processing Record 12 of Set 5 | crieff
# Processing Record 13 of Set 5 | pisco
# Processing Record 14 of Set 5 | makhambet
# Processing Record 15 of Set 5 | vilyuchinsk
# Processing Record 16 of Set 5 | athens
# Processing Record 17 of Set 5 | patnanungan
# Processing Record 18 of Set 5 | lompoc
# Processing Record 19 of Set 5 | iranshahr
# Processing Record 20 of Set 5 | nueva gerona
# Processing Record 21 of Set 5 | petrovka
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | nisa
# Processing Record 24 of Set 5 | burayevo
# Processing Record 25 of Set 5 | oualidia
# City not found. Skipping...
# Processing Record 26 of Set 5 | at taj
# Processing Record 27 of Set 5 | ocana
# Processing Record 28 of Set 5 | papatowai
# Processing Record 29 of Set 5 | kosh-agach
# Processing Record 30 of Set 5 | manatutu
# City not found. Skipping...
# Processing Record 31 of Set 5 | gore
# Processing Record 32 of Set 5 | tyukhtet
# Processing Record 33 of Set 5 | nago
# Processing Record 34 of Set 5 | jiuquan
# Processing Record 35 of Set 5 | necochea
# Processing Record 36 of Set 5 | santiago de cao
# Processing Record 37 of Set 5 | lluta
# Processing Record 38 of Set 5 | topchikha
# Processing Record 39 of Set 5 | shingu
# Processing Record 40 of Set 5 | xilitla
# Processing Record 41 of Set 5 | sunzha
# Processing Record 42 of Set 5 | macusani
# Processing Record 43 of Set 5 | orkney
# Processing Record 44 of Set 5 | ahau
# City not found. Skipping...
# Processing Record 45 of Set 5 | vorkuta
# Processing Record 46 of Set 5 | mejit
# Processing Record 47 of Set 5 | granville
# Processing Record 48 of Set 5 | acarau
# Processing Record 49 of Set 5 | namtsy
# Processing Record 0 of Set 6 | pong nam ron
# Processing Record 1 of Set 6 | anadyr
# Processing Record 2 of Set 6 | dudinka
# Processing Record 3 of Set 6 | vadso
# Processing Record 4 of Set 6 | drayton valley
# Processing Record 5 of Set 6 | solapur
# Processing Record 6 of Set 6 | puerto baquerizo moreno
# Processing Record 7 of Set 6 | lodja
# Processing Record 8 of Set 6 | marsh harbour
# Processing Record 9 of Set 6 | kapa'a
# Processing Record 10 of Set 6 | port alfred
# Processing Record 11 of Set 6 | garachico
# Processing Record 12 of Set 6 | richards bay
# Processing Record 13 of Set 6 | mariehamn
# Processing Record 14 of Set 6 | tongliao
# Processing Record 15 of Set 6 | nar'yan-mar
# Processing Record 16 of Set 6 | alice springs
# Processing Record 17 of Set 6 | fort bragg
# Processing Record 18 of Set 6 | syzran'
# Processing Record 19 of Set 6 | levokumskoye
# Processing Record 20 of Set 6 | saint croix
# Processing Record 21 of Set 6 | magistral'nyy
# Processing Record 22 of Set 6 | mount pearl
# Processing Record 23 of Set 6 | kotovsk
# Processing Record 24 of Set 6 | saint-joseph
# Processing Record 25 of Set 6 | sauri
# Processing Record 26 of Set 6 | mansa
# Processing Record 27 of Set 6 | kailua-kona
# Processing Record 28 of Set 6 | lahat
# Processing Record 29 of Set 6 | haiku-pauwela
# Processing Record 30 of Set 6 | south hedland
# Processing Record 31 of Set 6 | manaure
# Processing Record 32 of Set 6 | brandon
# Processing Record 33 of Set 6 | khovd
# Processing Record 34 of Set 6 | coquimbo
# Processing Record 35 of Set 6 | pemangkat
# Processing Record 36 of Set 6 | saudarkrokur
# Processing Record 37 of Set 6 | zhanibek
# Processing Record 38 of Set 6 | sorong
# Processing Record 39 of Set 6 | pitimbu
# Processing Record 40 of Set 6 | oppdal
# Processing Record 41 of Set 6 | namibe
# Processing Record 42 of Set 6 | tianpeng
# Processing Record 43 of Set 6 | klyuchi
# Processing Record 44 of Set 6 | egilsstadir
# Processing Record 45 of Set 6 | queenstown
# Processing Record 46 of Set 6 | luderitz
# Processing Record 47 of Set 6 | al burayqah
# Processing Record 48 of Set 6 | borogontsy
# Processing Record 49 of Set 6 | manakara
# Processing Record 0 of Set 7 | togur
# Processing Record 1 of Set 7 | sur
# Processing Record 2 of Set 7 | papao
# Processing Record 3 of Set 7 | sinop
# Processing Record 44 of Set 9 | ad dawadimi
# Processing Record 45 of Set 9 | vilyuysk
# Processing Record 46 of Set 9 | dunedin
# Processing Record 47 of Set 9 | letlhakeng
# Processing Record 48 of Set 9 | mandan
# Processing Record 49 of Set 9 | nova sintra
# Processing Record 0 of Set 10 | ayr
# Processing Record 1 of Set 10 | kapuskasing
# Processing Record 2 of Set 10 | mtambile
# Processing Record 3 of Set 10 | colonia
# Processing Record 4 of Set 10 | sol'tsy
# Processing Record 5 of Set 10 | mkushi
# Processing Record 6 of Set 10 | kyelang
# Processing Record 7 of Set 10 | bodo
# Processing Record 8 of Set 10 | kill devil hills
# Processing Record 9 of Set 10 | baruun-urt
# Processing Record 10 of Set 10 | vinh
# Processing Record 11 of Set 10 | geroskipou
# City not found. Skipping...
# Processing Record 12 of Set 10 | toliara
# Processing Record 13 of Set 10 | kijang
# Processing Record 14 of Set 10 | alofi
# Processing Record 15 of Set 10 | manokwari
# Processing Record 16 of Set 10 | tarawa
# Processing Record 17 of Set 10 | kalifornsky
# Processing Record 18 of Set 10 | qarah bagh
# Processing Record 19 of Set 10 | ascencion
# Processing Record 20 of Set 10 | kourou
# Processing Record 21 of Set 10 | hancheng
# Processing Record 22 of Set 10 | santa terezinha
# Processing Record 23 of Set 10 | anibare
# City not found. Skipping...
# Processing Record 24 of Set 10 | tchintabaraden
# Processing Record 25 of Set 10 | fuzesgyarmat
# Processing Record 26 of Set 10 | kongolo
# Processing Record 27 of Set 10 | sulak
# Processing Record 28 of Set 10 | bengkulu
# Processing Record 29 of Set 10 | illizi
# Processing Record 30 of Set 10 | happy valley-goose bay
# Processing Record 31 of Set 10 | kolonia town
# Processing Record 32 of Set 10 | afaahiti
# Processing Record 33 of Set 10 | winnemucca
# Processing Record 34 of Set 10 | beylagan
# City not found. Skipping...
# Processing Record 35 of Set 10 | ulsan
# Processing Record 36 of Set 10 | itacare
# Processing Record 37 of Set 10 | belmonte
# Processing Record 38 of Set 10 | kyren
# Processing Record 39 of Set 10 | portland
# Processing Record 40 of Set 10 | puerto colombia
# Processing Record 41 of Set 10 | ulanhot
# Processing Record 42 of Set 10 | crane
# Processing Record 43 of Set 10 | walvis bay
# Processing Record 44 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 45 of Set 10 | kaa-khem
# Processing Record 46 of Set 10 | nantucket
# Processing Record 47 of Set 10 | enterprise
# Processing Record 48 of Set 10 | cannonvale
# Processing Record 49 of Set 10 | asola
# Processing Record 0 of Set 11 | banff
# Processing Record 1 of Set 11 | caleta olivia
# Processing Record 2 of Set 11 | sechura
# Processing Record 3 of Set 11 | kiama
# Processing Record 4 of Set 11 | tosontsengel
# Processing Record 5 of Set 11 | martapura
# Processing Record 6 of Set 11 | port blair
# Processing Record 7 of Set 11 | lodwar
# Processing Record 8 of Set 11 | raduzhnyy
# Processing Record 9 of Set 11 | valley center
# Processing Record 10 of Set 11 | silver city
# Processing Record 11 of Set 11 | tierp
# Processing Record 12 of Set 11 | weno
# Processing Record 13 of Set 11 | bardai
# Processing Record 14 of Set 11 | qazvin
# Processing Record 15 of Set 11 | sant antoni de portmany
# Processing Record 16 of Set 11 | howrah
# Processing Record 17 of Set 11 | rio largo
# Processing Record 18 of Set 11 | letlhakane
# Processing Record 19 of Set 11 | arkhara
# Processing Record 20 of Set 11 | barah
# Processing Record 21 of Set 11 | tottori
# Processing Record 22 of Set 11 | ouani
# Processing Record 23 of Set 11 | gaoual
# Processing Record 24 of Set 11 | floro
# Processing Record 25 of Set 11 | quellon
# Processing Record 26 of Set 11 | tadine
# Processing Record 27 of Set 11 | san jose de mayo
# Processing Record 28 of Set 11 | ulaangom
# Processing Record 29 of Set 11 | aasiaat
# Processing Record 30 of Set 11 | ayaviri
# Processing Record 31 of Set 11 | ebon
# Processing Record 32 of Set 11 | altamira
# Processing Record 33 of Set 11 | gewane
# Processing Record 34 of Set 11 | nouadhibou
# Processing Record 35 of Set 11 | fada
# Processing Record 36 of Set 11 | amalapuram
# Processing Record 37 of Set 11 | trubchevsk
# Processing Record 38 of Set 11 | boa vista
# Processing Record 39 of Set 11 | acheng
# Processing Record 40 of Set 11 | vuktyl
# Processing Record 41 of Set 11 | nyons
# Processing Record 42 of Set 11 | kaoma
# Processing Record 43 of Set 11 | san jose village
# City not found. Skipping...
# Processing Record 44 of Set 11 | samitah
# Processing Record 45 of Set 11 | tabriz
# Processing Record 46 of Set 11 | lesnoy
# Processing Record 47 of Set 11 | eureka
# Processing Record 48 of Set 11 | usinsk
# Processing Record 49 of Set 11 | saint-philippe
# Processing Record 0 of Set 12 | ouesso
# Processing Record 1 of Set 12 | point pedro
# Processing Record 2 of Set 12 | mineiros
# Processing Record 3 of Set 12 | wotho
# Processing Record 4 of Set 12 | kainantu
# Processing Record 5 of Set 12 | trincomalee
# Processing Record 6 of Set 12 | termas de rio hondo
# Processing Record 7 of Set 12 | 'ibri
# City not found. Skipping...
# Processing Record 8 of Set 12 | dunay
# Processing Record 9 of Set 12 | hechuan
# Processing Record 10 of Set 12 | zhelezinka
# Processing Record 11 of Set 12 | salmon arm
# Processing Record 12 of Set 12 | al bardiyah
# Processing Record 13 of Set 12 | fort-shevchenko
# Processing Record 14 of Set 12 | maintirano
# Processing Record 15 of Set 12 | ocean pointe
# City not found. Skipping...
# Processing Record 16 of Set 12 | chegdomyn
# Processing Record 17 of Set 12 | las tablas
# Processing Record 18 of Set 12 | timimoun
# Processing Record 19 of Set 12 | brisas de zicatela
# Processing Record 20 of Set 12 | gulnar
# Processing Record 21 of Set 12 | villa zempoala
# Processing Record 22 of Set 12 | woolgoolga
# Processing Record 23 of Set 12 | nadi
# Processing Record 24 of Set 12 | tiznit
# Processing Record 25 of Set 12 | darwin
# Processing Record 26 of Set 12 | nabire
# Processing Record 27 of Set 12 | polatsk
# Processing Record 28 of Set 12 | yekaterinoslavka
# Processing Record 29 of Set 12 | fort-de-france
# Processing Record 30 of Set 12 | beidao
# Processing Record 31 of Set 12 | sumbe
# Processing Record 32 of Set 12 | riyadh
# Processing Record 33 of Set 12 | kamien pomorski
# Processing Record 34 of Set 12 | iquitos
# Processing Record 35 of Set 12 | qalat
# Processing Record 36 of Set 12 | cadale
# Processing Record 37 of Set 12 | savnik
# City not found. Skipping...
# Processing Record 38 of Set 12 | cuellar
# Processing Record 39 of Set 12 | bandarbeyla
# Processing Record 40 of Set 12 | revelstoke
# Processing Record 41 of Set 12 | santa elena de uairen
# Processing Record 42 of Set 12 | mil'kovo
# Processing Record 43 of Set 12 | beberibe
# Processing Record 44 of Set 12 | dapa
# Processing Record 45 of Set 12 | dolores
# Processing Record 46 of Set 12 | las lomas
# Processing Record 47 of Set 12 | xilin hot
# Processing Record 48 of Set 12 | leh
# Processing Record 49 of Set 12 | lu-uk
# Processing Record 0 of Set 13 | dhidhdhoo
# Processing Record 1 of Set 13 | qatana
# Processing Record 2 of Set 13 | aral
# Processing Record 3 of Set 13 | thunder bay
# Processing Record 4 of Set 13 | oxford
# Processing Record 5 of Set 13 | puqi
# Processing Record 6 of Set 13 | xianning
# Processing Record 7 of Set 13 | port said
# Processing Record 8 of Set 13 | topi
# Processing Record 9 of Set 13 | arkhangel'sk
# Processing Record 10 of Set 13 | shimoda
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          590
# Lat           590
# Lng           590
# Max Temp      590
# Humidity      590
# Cloudiness    590
# Wind Speed    590
# Country       590
# Date          590
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#                        City      Lat       Lng  Max Temp  Humidity  \
# 0               port arthur  38.8000  121.2667      6.12        66
# 1  petropavlovsk-kamchatsky  53.0452  158.6483      0.33        73
# 2                  bilibino  68.0546  166.4372    -15.31        94
# 3       fale old settlement  -9.3852 -171.2468     28.86        69
# 4                   kodinsk  58.6881   99.1844    -16.42        93
#
#    Cloudiness  Wind Speed Country        Date
# 0          51       13.28      CN  1699493730
# 1          20        9.39      RU  1699493446
# 2         100        1.09      RU  1699493731
# 3          93        4.84      TK  1699493731
# 4          18        0.77      RU  1699493732

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                     port arthur  38.8000  121.2667      6.12        66
# 1        petropavlovsk-kamchatsky  53.0452  158.6483      0.33        73
# 2                        bilibino  68.0546  166.4372    -15.31        94
# 3             fale old settlement  -9.3852 -171.2468     28.86        69
# 4                         kodinsk  58.6881   99.1844    -16.42        93
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                51       13.28      CN  1699493730
# 1                20        9.39      RU  1699493446
# 2               100        1.09      RU  1699493731
# 3                93        4.84      TK  1699493731
# 4                18        0.77      RU  1699493732

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (2023-11-08)")
plt.ylabel("Max Temperature (Celsius)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/WeatherPyFig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (2023-11-08)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/WeatherPyFig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (2023-11-08)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)


# Save the figure
plt.savefig("output_data/WeatherPyFig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (2023-11-08)")
plt.ylabel("Wind Speed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/WeatherPyFig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df
# Out:
#                              City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 0                     port arthur  38.8000  121.2667      6.12        66
# 1        petropavlovsk-kamchatsky  53.0452  158.6483      0.33        73
# 2                        bilibino  68.0546  166.4372    -15.31        94
# 4                         kodinsk  58.6881   99.1844    -16.42        93
# 5                         tindouf  27.6711   -8.1474     19.12        31
# ...                           ...      ...       ...       ...       ...
# 585                      xianning  29.8833  114.2167     18.49        92
# 586                     port said  31.2565   32.2841     23.99        73
# 587                          topi  34.0704   72.6236     17.28        39
# 588                  arkhangel'sk  64.5401   40.5433      0.63        99
# 589                       shimoda  34.6667  138.9500     19.20        64
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0                51       13.28      CN  1699493730
# 1                20        9.39      RU  1699493446
# 2               100        1.09      RU  1699493731
# 4                18        0.77      RU  1699493732
# 5                 0        4.93      DZ  1699493732
# ...             ...         ...     ...         ...
# 585             100        2.01      CN  1699493942
# 586              40        3.09      EG  1699493942
# 587              85        1.87      PK  1699493942
# 588             100        3.25      RU  1699493942
# 589             100        3.85      JP  1699493943
#
# [409 rows x 9 columns]

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df
# Out:
#                         City      Lat       Lng  Max Temp  Humidity  \
# City_ID
# 3        fale old settlement  -9.3852 -171.2468     28.86        69
# 7               port douglas -16.4833  145.4667     26.57        67
# 10                   mascote -15.5631  -39.3025     19.29        90
# 15                  cururupu  -1.8283  -44.8683     25.06        87
# 20                  waitangi -43.9535 -176.5597     10.74        76
# ...                      ...      ...       ...       ...       ...
# 556                   nabire  -3.3667  135.4833     28.29        78
# 561                    sumbe -11.2061   13.8437     24.66        86
# 564                  iquitos  -3.7481  -73.2472     25.02        88
# 572                 beberibe  -4.1797  -38.1306     26.17        80
# 574                  dolores -36.3132  -57.6792     10.69        69
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 3                93        4.84      TK  1699493731
# 7                22        4.17      AU  1699493733
# 10                0        0.84      BR  1699493733
# 15              100        2.00      BR  1699493735
# 20               40       11.78      NZ  1699493737
# ...             ...         ...     ...         ...
# 556              83        1.00      ID  1699493933
# 561             100        3.19      AO  1699493934
# 564              75        2.57      PE  1699493669
# 572              64        7.40      BR  1699493937
# 574              56        3.53      AR  1699493939
#
# [181 rows x 9 columns]

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# Perform a linear regression on temperature vs. latitude for northern hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(5, -20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7259231162086475

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# Perform a linear regression on temperature vs. latitude for southern hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
plt.annotate(line_eq,(-55, 32),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.430758020327995

# %% [markdown]
# **Discussion about the linear relationship:** Weather data from the Northern Hemisphere presents a strong negative correlation. As latitude increases, the max temp decreases. The Southern Hemisphere displays a weaker but visible positive correlation that as the latitude increases, the max temp also increases. Together, the plots show the relationship with temperature and the Earth's equator. As the latitude nears the equator at 0 degrees, the temperature increases.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# Perform a linear regression on humidity vs. latitude for northern hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(45, 20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.07148930603870952

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# Perform a linear regression on humidity vs. latitude for southern hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.annotate(line_eq,(-55, 20),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.05143638840619

# %% [markdown]
# **Discussion about the linear relationship:** Both hemispheres present weak r-values for the relationship between latitude and humidity. The data is very spread out in both cases, with little to no correlation displayed. Therefore, there is not a significant relationship between the two factors.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# Perform a linear regression on cloudiness vs. latitude for northern hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(35, 30),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.027161478757317184

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

# Perform a linear regression on cloudiness vs. latitude for southern hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.annotate(line_eq,(-55, 50),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.06889743315009873

# %% [markdown]
# **Discussion about the linear relationship:** Both hemispheres display positive slopes however, both r-values are relatively small. Each r-value is less than 0.1 indicating that there is no significant correlation between cloudiness and latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# Perform a linear regression on cloudiness vs. latitude for northern hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(10, 12),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.015425773100820083

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# Perform a linear regression on cloudiness vs. latitude for southern hemisphere
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))

# Create Plot
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")

# Label plot and annotate the line equation
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.annotate(line_eq,(-50, 13),fontsize=15,color="red")

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.021844791369301314

# %% [markdown]
# **Discussion about the linear relationship:** Neither the Northern or Southern Hemisphere shows a strong correlation between wind speed and latitude. There's a very slight decrease in wind speed when you near the equator (latitude 0 degrees) but not enough to be significant.
